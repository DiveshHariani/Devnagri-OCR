# %%
from PIL import Image
import pytesseract
import cv2
import matplotlib.pyplot as plt

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
image = cv2.imread(".\\image5.png")
print(type(image))
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
ret,thresh1 = cv2.threshold(rgb,127,255,cv2.THRESH_BINARY)
print(type(ret), type(thresh1))
plt.imshow(thresh1)
# Out:
# <class 'numpy.ndarray'>
# <class 'float'> <class 'numpy.ndarray'>

# %%
text = pytesseract.image_to_string(thresh1, lang="hin")
text
# Out:
# "शुदुरनु, दाग\n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\nनॉदवह्डी\n[महाराष्ट्र मीन महसूल अधिकार अभिलेख आणि नॉदवड्मा ( तयार करणे व सुस्थितीत ठेवणे ) नियम,१९७१ यातील नियम २९ |\nअंबिकापूर तातुका:- खामगाव .... जिल्\u200d्हा - बुलढाणा\nक्रमांक व उपविभाग : 70 _\nजागवीसाठी बल जिस\nषिकाखालील क्षेत्ाचा तपशील 'उपलब्धनसलेली | सिंचनाचे\nजमीन... | साधन\n______फोबपिकास्र्लील क्षेत्र] निर्मकपिकाखारलीतिक्षेत्र\nट्लाधकेयवेकाखालीर\nकेत्र\nश् कि नस अचल | जल [ अबल | दक [लि अचल तल ही\n|सिंचित सिंचित | नाव. | सिंचितर | सिंचित | नाव | सिंचित | सिंचित\n(९ | 0 (९ 0 थे 2 ) (१९ | हुए | (९९ | १९ (४ | 0९५४\nहेआर हि आर हे आर [हेआर हआर है आर हआर\nचीमी | चौमी चौमी | चौमी चौमी | चौमी चौमी\n:ठाद खिरप सियाबौना ब्य्व्ण कर «्उग्छा कहर\n9 खराब\nजा प्म्छा क्््णि\n५ ज्वि न ण्य््छ बिहिर\n20\nउिरप कपूर | ए्ण्नाज््| 03500 निटखराब ०3506\n५८ खिसेय कापूस ण्ञ् | रू | जन शिट्णग ०2500 बहिर\nशा\nजग ०3०० | ब्वरे | छठ\n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\nसुचना: या संकेतस्थव्ञावर दर्शवेतेली माहिती ही कोणत्याही शासकीय अथवा कायदेशीर बाबीसाठी वापरता येजार नाही.\n\n१५0 'पा€छ/ (0\n\x0c"
